# %% [markdown]
# # Multi-layered LSTM Lyrics Generation
#
# We train a language model on lyrics of Michael Jackson songs and try to generate lyrics from a seed text.

# %%
import utils.models as mdl
import utils.utils as utils
import tensorflow as tf

import numpy as np

# %%
#Load and preprocess data

data = utils.load_data('data/mj_lyrics.txt')

word2idx, idx2word, vocab_size = utils.word_idx_mappings(data,False)

#data = utils.generate_sample_data(data,time_steps)

data, lengths = utils.text2idx(data,word2idx)

data = utils.pad_data(data,lengths)

inputs, outputs = utils.make_input_output_pairs(data)

train_inputs, train_outputs,train_lengths, test_inputs, test_outputs, test_lengths = utils.generate_train_test_split(np.array(inputs), np.array(outputs), np.array(lengths))

# %%
train_outputs.shape
# Out:
# (6271, 59)

# %%
class LyricsGenLSTM:
    def __init__(self, name):
        self.name = name
        
    
    def build(self,vocab_size,data_dim,embedding_dims=32,num_hidden_units=128,learning_rate=1e-2,num_layers=2):
        
        with tf.variable_scope(self.name, reuse=tf.AUTO_REUSE):
            self.inputs = tf.placeholder(dtype=tf.int32, shape=[None,data_dim], name='inputs')
            self.labels = tf.placeholder(dtype=tf.int32, shape=[None,data_dim], name='outputs')
            self.lengths = tf.placeholder(dtype=tf.int32, shape=[None], name='lengths')
            
            self.non_zero_wts = tf.sign(self.labels)
            print(self.non_zero_wts.shape)
            self.non_zero_wts = tf.cast(tf.reshape(self.non_zero_wts,[-1]),tf.float32)
            print(self.non_zero_wts.shape)
            
            with tf.name_scope('embeddings'):
                self.embedding = tf.Variable(dtype=tf.float32, initial_value=tf.random_uniform([vocab_size,num_hidden_units],-1.0,1.0))
                self.em_lookup = tf.nn.embedding_lookup(self.embedding,self.inputs)
                #print(self.em_lookup.shape)
            with tf.name_scope('LSTM'):
                def make_cell():
                    cell = tf.contrib.rnn.LSTMCell(num_hidden_units)
                    cell = tf.contrib.rnn.DropoutWrapper(cell,output_keep_prob=0.5)
                    return cell
                self.layers = [make_cell() for _ in range(num_layers)]
                self.layers = tf.contrib.rnn.MultiRNNCell(self.layers)
                self.outputs,_ = tf.nn.dynamic_rnn(self.layers,self.em_lookup,dtype=tf.float32)
                self.Wo = tf.Variable(tf.random_normal([num_hidden_units,vocab_size]),dtype=tf.float32)
                self.bo = tf.Variable(tf.random_normal([vocab_size]),dtype=tf.float32)
                
                def out_layer(out):
                    return tf.matmul(out,self.Wo)+self.bo
                #self.logits = tf.map_fn(out_layer,self.outputs)
        
                self.logits = tf.layers.dense(self.outputs,vocab_size)
                print(self.logits.shape)
                self.softmax = tf.nn.softmax(self.logits,axis=2)
                self.logits2d = tf.reshape(self.logits,[-1,vocab_size])
            with tf.name_scope('Loss'):
                
                
                self.loss_all = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=self.logits2d,labels=tf.reshape(self.labels,[-1]))*self.non_zero_wts
                self.loss = tf.reduce_mean(self.loss_all)                
                
               # self.loss = tf.contrib.seq2seq.sequence_loss(logits=self.logits,targets=self.labels,
               #                                             weights=tf.sequence_mask(self.lengths,tf.shape(self.labels)[1], dtype=tf.float32),
               #                                             average_across_timesteps=True, average_across_batch=True)
                
                                 
                
            with tf.name_scope('train'):
                self.train_step = tf.train.AdamOptimizer(learning_rate).minimize(self.loss)
        return
    
    def train(self, batch_size, train_ip, train_op, lengths, epochs=10):
        self.session = tf.Session()
        s = self.session
        with s.as_default():
            s.run(tf.global_variables_initializer())
            
            for e in range(epochs):
                step=0
                print(f'Epoch {e+1}:')
                for batch_ids in utils.get_batch_idx(train_ip,batch_size):
                    _ = s.run([self.train_step], feed_dict={self.inputs:train_ip[batch_ids], self.labels:train_op[batch_ids], self.lengths:lengths[batch_ids]})
                    if step % 250 == 0:
                        tr_loss = s.run([self.loss],feed_dict={self.inputs:train_ip[batch_ids], self.labels:train_op[batch_ids], self.lengths:lengths[batch_ids]})
                        print(f'Iteration {step}, Training Loss: {tr_loss[0]}')
                        #print(l_a.shape)
                        #print(nnw)
                    step += 1
                self.predict(train_ip.shape[1],seed="She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,")

                    
                
                    
    
    def predict(self, max_len,length=15, seed='love'):
        print('Seed: ',seed)
        seq=''
        seed = seed.lower()
        #ixs=[]
        for i in range(length):
            seed_idx = [word2idx[wrd] for wrd in seed.split()]
            seed_ln=[len(seed_idx[i:])]
            seed_vec = seed_idx[i:] + [0]*(max_len-seed_ln[0])
            seed_vec = np.array(seed_vec)
            seed_vec = seed_vec[:,np.newaxis].T
            smx = self.session.run([self.softmax],feed_dict={self.inputs:seed_vec,self.lengths:(seed_ln)})[0]
            #idx = np.argmax(smx[seed_ln[0]-1,0,:])
            idx = np.argmax(smx[0,seed_ln[0]-1,:])
            seq += ' '+idx2word[idx]
            seed +=' '+ idx2word[idx]
        #print(ixs)
        #ixs=[]
        print(seq)

# %%
rnn = LyricsGenLSTM('MJ_Lyrics_Gen')
rnn.build(vocab_size,np.max(lengths)-1)
# Out:
# (?, 59)
# (?,)
# (?, 59, 3675)

# %%
rnn.train(batch_size=256,train_ip=train_inputs,train_op=train_outputs,lengths=train_lengths,epochs=50)
# Out:
# Epoch 1:
# Iteration 0, Training Loss: 0.6786337494850159
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  the to to to to you you the to to to you you you you
# Epoch 2:
# Iteration 0, Training Loss: 0.49414217472076416
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  the you you the the the you you you you you you you you you
# Epoch 3:
# Iteration 0, Training Loss: 0.5260891318321228
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  the to the the to the the you the the to the to the to
# Epoch 4:
# Iteration 0, Training Loss: 0.4714902341365814
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  the the a the got the the got you the a a a the the
# Epoch 5:
# Iteration 0, Training Loss: 0.461159884929657
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  the way you the heart to the girl the way you the way you the
# Epoch 6:
# Iteration 0, Training Loss: 0.4744093418121338
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to the way you love the world of the world of the way you the
# Epoch 7:
# Iteration 0, Training Loss: 0.4462498426437378
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  the way you know the world you know a way you feel to the way
# Epoch 8:
# Iteration 0, Training Loss: 0.4486173093318939
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to you the way you be to the world is the way you the way
# Epoch 9:
# Iteration 0, Training Loss: 0.4074132442474365
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  and i know the way you the way you know you love to be the
# Epoch 10:
# Iteration 0, Training Loss: 0.40116339921951294
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to be to the way you love the love and be the world are the
# Epoch 11:
# Iteration 0, Training Loss: 0.37455686926841736
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to be there baby to be there and i want to be baby with me
# Epoch 12:
# Iteration 0, Training Loss: 0.35421261191368103
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to the way you love the love that i am a blue girl that i
# Epoch 13:
# Iteration 0, Training Loss: 0.35830992460250854
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  and you can feel the world you can be there love is be the world
# Epoch 14:
# Iteration 0, Training Loss: 0.34537798166275024
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to be there out on the floor in the rhythm in the way you are
# Epoch 15:
# Iteration 0, Training Loss: 0.3299082815647125
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  day the world i got to see the better place to be my tree? then
# Epoch 16:
# Iteration 0, Training Loss: 0.3070563077926636
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  no love you better cause i can feel the faith in black for shining and
# Epoch 17:
# Iteration 0, Training Loss: 0.31468063592910767
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  baby give me to you, baby beat it do you feel it so baby you
# Epoch 18:
# Iteration 0, Training Loss: 0.30724990367889404
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to change the world without the wall i can feel where you want to be
# Epoch 19:
# Iteration 0, Training Loss: 0.3002905249595642
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to shake me baby just to be there much there just a friend of mine
# Epoch 20:
# Iteration 0, Training Loss: 0.30069440603256226
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to be yourself too out to a got to be a monster yun, to fame
# Epoch 21:
# Iteration 0, Training Loss: 0.3019542694091797
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to shake my family tree? tree? no is for the faith in a wall she
# Epoch 22:
# Iteration 0, Training Loss: 0.2897248864173889
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  seen through the same way you do it? can you feel it? can you feel
# Epoch 23:
# Iteration 0, Training Loss: 0.2790253758430481
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to see the world we can believe in the way you are, girl needs the
# Epoch 24:
# Iteration 0, Training Loss: 0.2915150225162506
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to you, that's with you, right to be a day i don't want to be
# Epoch 25:
# Iteration 0, Training Loss: 0.260634183883667
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to you, that's its baby is a been one feeling in the wall i can
# Epoch 26:
# Iteration 0, Training Loss: 0.2648102641105652
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  through and singing and crawlin' out on the nite line down down a wall one
# Epoch 27:
# Iteration 0, Training Loss: 0.27250975370407104
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  round too more to it before you can see you baby baby, yeah yeah not
# Epoch 28:
# Iteration 0, Training Loss: 0.26175668835639954
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  too got to be there out to take i cry trough, day no day to
# Epoch 29:
# Iteration 0, Training Loss: 0.2502661347389221
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  too soon for me and romance long thing to be overcome around a air, is,
# Epoch 30:
# Iteration 0, Training Loss: 0.2668103575706482
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to you, i can fly near the kabah tops what i just hold, be there,
# Epoch 31:
# Iteration 0, Training Loss: 0.2513998746871948
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to take me game today they just can't let it be no king, matter i
# Epoch 32:
# Iteration 0, Training Loss: 0.25459763407707214
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  with you, do you feel the faith without the way that i stare the way
# Epoch 33:
# Iteration 0, Training Loss: 0.24176451563835144
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  right to slowly on the ground i just win nothin' to start abusing the muslim.
# Epoch 34:
# Iteration 0, Training Loss: 0.24027270078659058
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to overload crazy quit yeah yeah yeah, yeah, baby yeah yeah yeah yeah god i
# Epoch 35:
# Iteration 0, Training Loss: 0.24914133548736572
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  too got to be there than just another damn in for the world you know
# Epoch 36:
# Iteration 0, Training Loss: 0.2396569699048996
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  pride for you and rise for jump baby cry 'cause i kiss, no mine and
# Epoch 37:
# Iteration 0, Training Loss: 0.23673684895038605
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  slapped in the dawn to you feel it? can you feel it? can you feel
# Epoch 38:
# Iteration 0, Training Loss: 0.23321937024593353
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  at the fire of the brand zone day?... out around my long in the big
# Epoch 39:
# Iteration 0, Training Loss: 0.2444853037595749
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  too much to you dirt in the bed of conquest right sorrow from us instant
# Epoch 40:
# Iteration 0, Training Loss: 0.2333279401063919
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  a oh! as then you've got to see you flag naive. out and a sword
# Epoch 41:
# Iteration 0, Training Loss: 0.23941372334957123
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  too much behind the number i don't can't stop tickle dream again being blurring your
# Epoch 42:
# Iteration 0, Training Loss: 0.24059835076332092
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  a long, got away and you'll see the signs thing don't be far without to
# Epoch 43:
# Iteration 0, Training Loss: 0.24575957655906677
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  for sense. to let you feel cry hair" hey hey hey hey hey hey up
# Epoch 44:
# Iteration 0, Training Loss: 0.23273691534996033
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  known i'll be there alright, matter what i want to do stop to stay across
# Epoch 45:
# Iteration 0, Training Loss: 0.23790068924427032
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to you, then you am where it's mi for still i can stay? souls again
# Epoch 46:
# Iteration 0, Training Loss: 0.21318449079990387
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  too magazine behind the bend promising, i am the loser, baby i am the four
# Epoch 47:
# Iteration 0, Training Loss: 0.22595980763435364
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  known waiting and boogie york long that has shed a loser, yeah yeah yeah on
# Epoch 48:
# Iteration 0, Training Loss: 0.2177933007478714
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  there to eat it loud just a king, too bad too soon to you, that's
# Epoch 49:
# Iteration 0, Training Loss: 0.2291364222764969
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  to see that rest on the ground when i can be there are all perfect
# Epoch 50:
# Iteration 0, Training Loss: 0.22031350433826447
# Seed:  She was more like a beauty queen from a movie scene I said don't mind, but what do you mean,
#  too as burns about you to me cry, cry cry and myself. with you gave

# %%
seed = "I took my baby on a Saturday bang Boy is that girl with you? Yes, we're one and the same Now I believe in miracles"

rnn.predict(seed=seed,max_len=np.max(lengths)-1,length=100)
# Out:
# Seed:  I took my baby on a Saturday bang Boy is that girl with you? Yes, we're one and the same Now I believe in miracles
#  the years in the world that we've children shows diamonds there sold the world you were up my love you delirious up i can glorify it oh what is god planing, times better good like you do. cry time will be there, are you sing pride again jackson huh! to live my independently- through my girl till expression baby, yeah yeah yeah yeah yeah yeah yeah yeah yeah yeah yeah yeah yeah yeah yeah oo! yeah yeah wrong yeah yeah yeah yeah yeah yeah yeah, yeah forgive in yourself a babe - yun, for its now that it's not dreamin'
